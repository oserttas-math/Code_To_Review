# %%
# Data Analysis #
import pandas as pd 
import numpy as np
import re

# Graphics #
import matplotlib.pyplot as plt
import seaborn as sns
#import geopandas
#from shapely.geometry import Point
# %matplotlib inline

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Set default font size
plt.rcParams['font.size'] = 24

# ML packages #

# Splitting data into training and testing
from sklearn.model_selection import train_test_split

# %%
# Data #
tag = 'Healthy_Aging_Data1.csv'
raw_df = pd.read_csv(tag)
raw_df.sample(5)
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc Datasource  \
# 1053        2014     2014           SD    South Dakota      BRFSS
# 9208        2013     2013           HI          Hawaii      BRFSS
# 13314       2012     2012           SC  South Carolina      BRFSS
# 34602       2016     2016           AZ         Arizona      BRFSS
# 11742       2012     2012           SC  South Carolina      BRFSS
#
#                                      Class  \
# 1053                        Overall Health
# 9208               Screenings and Vaccines
# 13314                       Overall Health
# 34602  Nutrition/Physical Activity/Obesity
# 11742  Nutrition/Physical Activity/Obesity
#
#                                                    Topic  \
# 1053                       Oral health:  tooth retention
# 9208                  Influenza vaccine within past year
# 13314    Physically unhealthy days (mean number of days)
# 34602  No leisure time physical activity within past ...
# 11742                      Eating 2 or more fruits daily
#
#                                                 Question  Response  \
# 1053   Percentage of older adults who report having l...       NaN
# 9208   Percentage of older adults who reported influe...       NaN
# 13314  Physically unhealthy days (mean number of days...       NaN
# 34602  Percentage of older adults who have not had an...       NaN
# 11742  Percentage of older adults who are eating 2 or...       NaN
#
#       Data_Value_Unit DataValueTypeID Data_Value_Type  Data_Value  \
# 1053                %           PRCTG      Percentage        60.9
# 9208                %           PRCTG      Percentage        51.6
# 13314          Number            MEAN            Mean         6.6
# 34602               %           PRCTG      Percentage        28.2
# 11742               %           PRCTG      Percentage         NaN
#
#        Data_Value_Alt Data_Value_Footnote_Symbol Data_Value_Footnote  \
# 1053              NaN                        NaN                 NaN
# 9208              NaN                        NaN                 NaN
# 13314             NaN                        NaN                 NaN
# 34602             NaN                        NaN                 NaN
# 11742             NaN                          ~   No Data Available
#
#        Low_Confidence_Limit  High_Confidence_Limit  Sample_Size  \
# 1053                   57.5                   64.1          NaN
# 9208                   46.6                   56.6          NaN
# 13314                   5.8                    7.5          NaN
# 34602                  24.8                   32.0          NaN
# 11742                   NaN                    NaN          NaN
#
#       StratificationCategory1    Stratification1 StratificationCategory2  \
# 1053                Age Group  65 years or older                     NaN
# 9208                Age Group        60-64 years                     NaN
# 13314               Age Group        55-59 years                     NaN
# 34602               Age Group        60-64 years                     NaN
# 11742               Age Group        50-54 years                     NaN
#
#       Stratification2  StratificationCategory3  Stratification3  \
# 1053              NaN                      NaN              NaN
# 9208              NaN                      NaN              NaN
# 13314             NaN                      NaN              NaN
# 34602             NaN                      NaN              NaN
# 11742             NaN                      NaN              NaN
#
#                                      GeoLocation ClassID TopicID QuestionID  \
# 1053    (44.353130053000484, -100.3735306369997)     C01   TOC05        Q07
# 9208   (21.304850435000446, -157.85774940299973)     C03   TSC08        Q18
# 13314   (33.998821303000454, -81.04537120699968)     C01   TOC01        Q08
# 34602  (34.865970280000454, -111.76381127699972)     C02   TNC03        Q16
# 11742   (33.998821303000454, -81.04537120699968)     C02   TNC01        Q01
#
#        ResponseID  LocationID StratificationCategoryID1 StratificationID1  \
# 1053          NaN          46                       AGE            65PLUS
# 9208          NaN          15                       AGE              6064
# 13314         NaN          45                       AGE              5559
# 34602         NaN           4                       AGE              6064
# 11742         NaN          45                       AGE              5054
#
#       StratificationCategoryID2 StratificationID2  StratificationCategoryID3  \
# 1053                        NaN               NaN                        NaN
# 9208                        NaN               NaN                        NaN
# 13314                       NaN               NaN                        NaN
# 34602                       NaN               NaN                        NaN
# 11742                       NaN               NaN                        NaN
#
#        StratificationID3  Report
# 1053                 NaN     NaN
# 9208                 NaN     NaN
# 13314                NaN     NaN
# 34602                NaN     NaN
# 11742                NaN     NaN

# %%
filt_cognitive = raw_df['Class'] == 'Cognitive Decline'
cognitive_df = raw_df[filt_cognitive]

# %%
def drop_empty_columns(df):
    ''' Drop Empty Columns From A DataFrame'''
    all_empty = df.shape[0]
    to_be_dropped = [cols for cols in df.columns if df[cols].isnull().sum() == all_empty ]
    print(to_be_dropped)
    df = df.drop(columns=to_be_dropped)
    return df

# %%
cognitive_df = drop_empty_columns(cognitive_df)
check_units = [col for col in cognitive_df if col.startswith('Data')]
if 'Data_Value' in check_units:
    check_units.remove('Data_Value')
    cognitive_df = cognitive_df.drop(columns=check_units)
# Out:
# []

# %%
to_drop = ['GeoLocation',
          'StratificationID1',
          'QuestionID',
          'LocationID',
          'ClassID',
          'TopicID',
          'LocationDesc',
          'StratificationCategoryID1',
          'StratificationCategoryID2',
          'StratificationID2',
          'StratificationCategory1',
          'StratificationCategory2'
          ]
cognitive_df_clean = cognitive_df.drop(columns=to_drop)

# %%
def missing_values_table(df):
    '''Calculate Missing Values of Each Column'''
    # Total missing amount in each feature /series type
    missing_value = df.isnull().sum()

    # Percentage of that missing values in its column /series type
    miss_percent = 100*missing_value/df.shape[0]

    # Make a table of calculated fields /will make dataframe
    table = pd.concat([missing_value, miss_percent], axis=1).rename(
        columns={0: 'Missing Values', 1: '% of Total Values'})

    # Sort by percentages column
    table.sort_values(by=['% of Total Values'], ascending=False,
                      inplace=True)

    # Print Summary Information
    print('\nThe DataFrame has ' + str(df.shape[1]) + ' columns.\n'
          'There are ' + str(table.shape[0]) + ' columns that have missing values')

    return table

missing_values_table(cognitive_df_clean)
# Out:
# The DataFrame has 11 columns.
# There are 11 columns that have missing values
#                        Missing Values  % of Total Values
# Stratification2                  3304          89.393939
# Data_Value                       1618          43.777056
# Low_Confidence_Limit             1618          43.777056
# High_Confidence_Limit            1618          43.777056
# YearStart                           0           0.000000
# YearEnd                             0           0.000000
# LocationAbbr                        0           0.000000
# Class                               0           0.000000
# Topic                               0           0.000000
# Question                            0           0.000000
# Stratification1                     0           0.000000

# %%
missing_df = missing_values_table(cognitive_df_clean)
missing_columns = list(missing_df[missing_df['% of Total Values'] > 50.0].index)
print('We will remove {} column(s).'.format(missing_columns))
# Out:
# The DataFrame has 11 columns.
# There are 11 columns that have missing values
# We will remove ['Stratification2'] column(s).

# %%
cognitive_df_clean = cognitive_df_clean.drop(columns=list(missing_columns))

# %% [markdown]
# # This is the dataframe I am working on

# %%
cognitive_df_clean[['LocationAbbr', 'YearStart','Stratification1', 'Data_Value']]
# Out:
#       LocationAbbr  YearStart    Stratification1  Data_Value
# 21919           US       2011        50-54 years        10.2
# 21920           US       2011        50-54 years         9.0
# 21921           US       2011        50-54 years         8.0
# 21922           US       2011        50-54 years         9.8
# 21923           US       2011        50-54 years        10.7
# 21924           US       2011        50-54 years        26.2
# 21925           US       2011        50-54 years         9.2
# 21926           AL       2011        50-54 years         NaN
# 21927           AK       2011        50-54 years         NaN
# 21928           AZ       2011        50-54 years         NaN
# 21929           AR       2011        50-54 years         NaN
# 21930           CA       2011        50-54 years         NaN
# 21931           CO       2011        50-54 years         NaN
# 21932           CT       2011        50-54 years         NaN
# 21933           DE       2011        50-54 years         NaN
# 21934           DC       2011        50-54 years         NaN
# 21935           FL       2011        50-54 years         NaN
# 21936           GA       2011        50-54 years         NaN
# 21937           GU       2011        50-54 years         NaN
# 21938           HI       2011        50-54 years        11.0
# 21939           ID       2011        50-54 years         NaN
# 21941           IL       2011        50-54 years         8.5
# 21942           IN       2011        50-54 years         NaN
# 21943           IA       2011        50-54 years         NaN
# 21944           KS       2011        50-54 years         NaN
# 21945           KY       2011        50-54 years         NaN
# 21946           LA       2011        50-54 years         NaN
# 21947           ME       2011        50-54 years         NaN
# 21948           MD       2011        50-54 years         NaN
# 21949           MA       2011        50-54 years         NaN
# ...            ...        ...                ...         ...
# 42674           US       2015        60-64 years        52.0
# 42675           US       2015  65 years or older        41.8
# 42676           US       2015        50-54 years        48.4
# 42677           US       2015        55-59 years        52.5
# 42678           US       2015        60-64 years        45.0
# 42679           US       2015  65 years or older        34.9
# 42680           US       2015        50-54 years        47.9
# 42681           US       2015        55-59 years        52.0
# 42682           US       2015        60-64 years        53.4
# 42683           US       2015  65 years or older        61.6
# 42684           US       2015        50-54 years        37.1
# 42685           US       2015        55-59 years        36.8
# 42686           US       2015        60-64 years        58.7
# 42687           US       2015  65 years or older        43.8
# 42688           US       2015        50-54 years        20.5
# 42689           US       2015        55-59 years        39.8
# 42690           US       2015        60-64 years        55.1
# 42691           US       2015  65 years or older        23.8
# 42692           US       2015        50-54 years        28.6
# 42693           US       2015        55-59 years        17.1
# 42694           US       2015        60-64 years        31.7
# 42695           US       2015  65 years or older        23.5
# 42696           US       2015        50-54 years        88.3
# 42697           US       2015        55-59 years        25.8
# 42698           US       2015        60-64 years        55.0
# 42699           US       2015  65 years or older        63.0
# 42700           US       2015        50-54 years        49.0
# 42701           US       2015        55-59 years        73.4
# 42702           US       2015        60-64 years        52.0
# 42703           US       2015  65 years or older        48.8
#
# [3696 rows x 4 columns]

# %% [markdown]
#  **I want to fill missing values in Data_Value column taking mean of sub group it is in. i.e. If State is AZ and Year 2015 and 50-54 year old then take the mean of Data_Value and fill nan in this small group**.
#
#  Code below takes infinite time to do work. I actually did not get anything out of it. Could you recommend me soem other ways?

# %%
for i in cognitive_df_clean.LocationAbbr:
    for j in cognitive_df_clean.YearStart:
        for k in cognitive_df_clean.Stratification1:
            age_grp = cognitive_df_clean['Stratification1'] == k
            state = cognitive_df_clean['LocationAbbr'] == i 
            year = cognitive_df_clean['YearStart'] == j 
            avg = cognitive_df_clean.loc[state  & age_grp, 'Data_Value'].mean()
            cognitive_df_clean.loc[state & year & age_grp, 'Data_Value'].fillna(avg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-32cca23bd54c> in <module>()
#       5             state = cognitive_df_clean['LocationAbbr'] == 'WY'
#       6             avg = cognitive_df_clean.loc[state  & age_grp, 'Data_Value'].mean()
# ----> 7             cognitive_df_clean.loc[state & year & age_grp, 'Data_Value'].fillna(avg)
#       8
#
# NameError: name 'year' is not defined
